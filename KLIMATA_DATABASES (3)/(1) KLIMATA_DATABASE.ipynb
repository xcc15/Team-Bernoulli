# %% [markdown]
# ## KLIMATA ILOILO DATABASE CREATION

# %% [markdown]
# ###  After the data preprocessing, we created a SQL database for the datasets to store, organize, and efficiently manage multiple related tables so they can be easily queried, linked, and updated during analysis.

# %%
import os
import sqlite3
import pandas as pd

# Folder where your CSV files are stored
folder_path = r"C:\Users\Value Lines\Documents\FINAL_DATASETS"

#  Create or connect to a local SQLite database
conn = sqlite3.connect("final_datasets.db")
cursor = conn.cursor()

# Loop through all CSV files in the folder
for file in os.listdir(folder_path):
    if file.endswith(".csv"):
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)

        # Use file name (without extension) as table name
        table_name = os.path.splitext(file)[0]

        # Save DataFrame as a SQL table
        df.to_sql(table_name, conn, if_exists="replace", index=False)
        print(f" Saved {table_name} to database")

conn = sqlite3.connect("final_datasets.db")
cursor = conn.cursor()

# Confirm saved tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("\n📋 Tables in database:")
for t in tables:
    print("-", t[0])

# Close the connection
conn.close()
print("\n Database created successfully: final_datasets.db")
# Out:
#  Saved AMENITY_FINAL to database
#  Saved CLIMATE_FINALE to database
#  Saved HEALTH_FINAL to database
#  Saved POPULATION_FINAL to database
#  Saved RWI_FINAL to database
#
# 📋 Tables in database:
# - AMENITY_FINAL
# - CLIMATE_FINALE
# - HEALTH_FINAL
# - POPULATION_FINAL
# - RWI_FINAL
#
#  Database created successfully: final_datasets.db

# %%
# Check if tables is a DataFrame or list

conn = sqlite3.connect("final_datasets.db")

if isinstance(tables, pd.DataFrame):
    table_names = tables['name'].tolist()
else:
    table_names = [t[0] for t in tables]  # if it's a list of tuples

# Loop through and preview first 5 rows of each table
for table in table_names:
    print(f"\n📄 First 5 rows of table: {table}")
    preview = pd.read_sql(f"SELECT * FROM {table} LIMIT 5;", conn)
    print(preview)
    
conn.close()
# Out:
# 📄 First 5 rows of table: AMENITY_FINAL
#           uuid   adm4_pcode        date  college_nearest  \
# 0  osmpa001e83  ph063022075  2022-01-01       499.693700
# 1  osmpa001cac  ph063022085  2022-01-01       190.538945
# 2  osmpa001cab  ph063022132  2022-01-01       249.824455
# 3  osmpa001caa  ph063022092  2022-01-01       554.897237
# 4  osmpa001ca9  ph063022054  2022-01-01        11.836872
#
#    community_centre_nearest  school_nearest  shelter_nearest  \
# 0                363.721118      196.962495       396.840748
# 1                294.050675        0.000000       755.295238
# 2                554.323482      212.821448       600.801916
# 3                553.326752      238.790126      1168.852374
# 4                332.472393        0.000000       396.790167
#
#    town_hall_nearest  university_nearest             location1.adm4_en  \
# 0           0.000000          457.790233  delgado-jalandoni-bagumbayan
# 1         524.007659          348.098929                        laguda
# 2          79.373668         1151.978301                progreso-lapuz
# 3           0.000000         1370.429642                libertad-lapuz
# 4         309.502693          988.501036                      edganzon
#
#    location1.brgy_total_area
# 0                     0.0235
# 1                     0.0537
# 2                     0.2741
# 3                     0.0383
# 4                     0.1033
#
# 📄 First 5 rows of table: CLIMATE_FINALE
#     adm4_pcode        date  ndvi         uuid   no2      co   so2     o3  \
# 0  ph063022001  2003-01-01  0.47  cairq61f770  1.21  0.0845  0.41  33.08
# 1  ph063022001  2003-01-02  0.48  cairq0d5fc0  0.72  0.0940  0.29  37.59
# 2  ph063022001  2003-01-03  0.44  cairq0d5fc1  0.89  0.0914  0.33  37.41
# 3  ph063022001  2003-01-04  0.48  cairq0d5fc2  0.71  0.0860  0.31  37.28
# 4  ph063022001  2003-01-05  0.44  cairq0d5fc3  0.66  0.0862  0.34  35.99
#
#     pm10   pm25  heat_index    pr     adm4_en  brgy_total_area
# 0  20.72  14.15       28.73  6.17  santa cruz           0.5633
# 1  24.16  14.37       26.73  0.00  santa cruz           0.5633
# 2  19.79  12.34       27.12  0.00  santa cruz           0.5633
# 3  20.64  12.88       27.69  0.00  santa cruz           0.5633
# 4  17.62  10.76       27.13  0.00  santa cruz           0.5633
#
# 📄 First 5 rows of table: HEALTH_FINAL
#           uuid   adm4_pcode        date  \
# 0  mbiso000078  ph063022001  2022-01-01
# 1  mbiso000079  ph063022003  2022-01-01
# 2  mbiso00007a  ph063022004  2022-01-01
# 3  mbiso00007b  ph063022005  2022-01-01
# 4  mbiso00007c  ph063022006  2022-01-01
#
#    brgy_healthcenter_pop_reached_pct_5min  \
# 0                                  100.00
# 1                                   54.64
# 2                                   84.84
# 3                                   99.22
# 4                                   82.85
#
#    brgy_healthcenter_pop_reached_pct_15min  \
# 0                                   100.00
# 1                                    54.64
# 2                                    98.23
# 3                                    99.22
# 4                                    82.85
#
#    brgy_healthcenter_pop_reached_pct_30min  hospital_pop_reached_pct_5min  \
# 0                                   100.00                           0.00
# 1                                    54.64                           0.00
# 2                                    98.23                          77.88
# 3                                    99.22                           0.00
# 4                                    82.85                          11.01
#
#    hospital_pop_reached_pct_15min  hospital_pop_reached_pct_30min  \
# 0                           99.95                          100.00
# 1                           54.64                           54.64
# 2                           98.23                           98.23
# 3                           99.22                           99.22
# 4                           82.85                           82.85
#
#    rhu_pop_reached_pct_5min  rhu_pop_reached_pct_15min  \
# 0                     78.41                     100.00
# 1                     54.64                      54.64
# 2                     73.20                      98.23
# 3                     99.22                      99.22
# 4                     71.84                      82.85
#
#    rhu_pop_reached_pct_30min                    adm4_en  brgy_total_area
# 0                     100.00                 santa cruz           0.5633
# 1                      54.64                  aguinaldo           0.0652
# 2                      98.23  airport (tabucan airport)           1.0117
# 3                      99.22             alalasan lapuz           0.0729
# 4                      82.85                  arguelles           0.1224
#
# 📄 First 5 rows of table: POPULATION_FINAL
#           uuid   adm4_pcode        date  pop_count_total  pop_count_mean  \
# 0  wdpop000001  ph063022152  2000-01-01      1492.030518       14.346447
# 1  wdpop000002  ph063022015  2000-01-01       688.092651       45.872843
# 2  wdpop000003  ph063022118  2000-01-01      1734.744507      133.441885
# 3  wdpop000018  ph063022040  2000-01-01      1891.350830       61.011317
# 4  wdpop000019  ph063022020  2000-01-01      2018.401123      288.343018
#
#    pop_count_median  pop_count_stdev  pop_count_min  pop_count_max  \
# 0         14.088117         9.941083       1.157729      39.577888
# 1         46.660271         6.994909      30.479767      55.304688
# 2         18.758980       247.449747      11.151038     968.687927
# 3         60.119343        28.049733      17.409624     128.819382
# 4        268.530884       124.519965     130.097717     472.024048
#
#               adm4_en  brgy_total_area
# 0      hibao-an norte           0.8800
# 1              bantud           0.1261
# 2      north baluarte           0.1259
# 3            cuartero           0.2656
# 4  monica blumentritt           0.0626
#
# 📄 First 5 rows of table: RWI_FINAL
#           uuid   adm4_pcode        date   rwi_max  rwi_mean  rwi_median  \
# 0  tmrwi000002  ph063022043  2016-01-01  0.623478  0.605305    0.611521
# 1  tmrwi000006  ph063022042  2016-01-01  0.561553  0.541626    0.538265
# 2  tmrwi000008  ph063022041  2016-01-01  0.687071  0.645999    0.648772
# 3  tmrwi00000c  ph063022040  2016-01-01  0.593314  0.564654    0.564498
# 4  tmrwi00000e  ph063022038  2016-01-01  0.647317  0.621072    0.617565
#
#     rwi_min   rwi_std            adm4_en  brgy_total_area
# 0  0.580916  0.021951     mabolo-delgado           0.0524
# 1  0.530066  0.012550              danao           0.1989
# 2  0.572029  0.034743              cubay           1.0505
# 3  0.536304  0.028023           cuartero           0.2656
# 4  0.601839  0.020932  concepcion-montes           0.2205
